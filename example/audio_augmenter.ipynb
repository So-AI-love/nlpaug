# %% [markdown]
# <a href="https://colab.research.google.com/github/So-AI-love/nlpaug/blob/master/example/audio_augmenter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Config

# %%
# !pip install nlpaug
# Out:
# Requirement already satisfied: nlpaug in /usr/local/lib/python3.7/dist-packages (1.1.3)

# %%
import nlpaug
nlpaug.__version__
# Out:
# '1.1.3'

# %%
import nlpaug.augmenter.audio as naa

from nlpaug.util.audio.visualizer import AudioVisualizer

# %%
# !git clone https://github.com/makcedward/nlpaug
# !find -name Yamaha-V50-Rock-Beat-120bpm.wav
# %cd '/content/nlpaug/'
# Out:
# fatal: destination path 'nlpaug' already exists and is not an empty directory.
# ./test/res/audio/Yamaha-V50-Rock-Beat-120bpm.wav
# ./test/nlpaug/test/res/audio/Yamaha-V50-Rock-Beat-120bpm.wav
# /content/nlpaug

# %%
import librosa
import librosa.display as librosa_display
import matplotlib.pyplot as plt

file_path = 'Yamaha-V50-Rock-Beat-120bpm.wav'
file_path = '/content/nlpaug/test/res/audio/' + file_path
data, sr = librosa.load(file_path)

# %% [markdown]
# # Crop Augmenter

# %%
aug = naa.CropAug(sampling_rate=sr)
augmented_data = aug.augment(data)

librosa_display.waveplot(augmented_data, sr=sr, alpha=0.5)
librosa_display.waveplot(data, sr=sr, color='r', alpha=0.25)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Loudness Augmenter

# %%
aug = naa.LoudnessAug()
augmented_data = aug.augment(data)

librosa_display.waveplot(augmented_data, sr=sr, alpha=0.25)
librosa_display.waveplot(data, sr=sr, color='r', alpha=0.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Mask Augmenter

# %%
aug = naa.MaskAug(sampling_rate=sr, mask_with_noise=False)
augmented_data = aug.augment(data)

librosa_display.waveplot(data, sr=sr, alpha=0.5)
librosa_display.waveplot(augmented_data, sr=sr, color='r', alpha=0.25)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Noise

# %%
aug = naa.NoiseAug()
augmented_data = aug.augment(data)

librosa_display.waveplot(data, sr=sr, alpha=0.5)
librosa_display.waveplot(augmented_data, sr=sr, color='r', alpha=0.25)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Pitch Augmenter

# %%
aug = naa.PitchAug(sampling_rate=sr, factor=(2,3))
augmented_data = aug.augment(data)

librosa_display.waveplot(data, sr=sr, alpha=0.5)
librosa_display.waveplot(augmented_data, sr=sr, color='r', alpha=0.25)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Shift Augmenter

# %%
aug = naa.ShiftAug(sampling_rate=sr)
augmented_data = aug.augment(data)

librosa_display.waveplot(data, sr=sr, alpha=0.5)
librosa_display.waveplot(augmented_data, sr=sr, color='r', alpha=0.25)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Speed Augmenter

# %%
aug = naa.SpeedAug()
augmented_data = aug.augment(data)

librosa_display.waveplot(data, sr=sr, alpha=0.5)
librosa_display.waveplot(augmented_data, sr=sr, color='r', alpha=0.25)

plt.tight_layout()
plt.show()

# %% [markdown]
# # VTLP Augmenter

# %%
aug = naa.VtlpAug(sampling_rate=sr)
augmented_data = aug.augment(data)

AudioVisualizer.freq_power('VTLP Augmenter', data, sr, augmented_data)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# # Normalize Augmenter

# %%
aug = naa.NormalizeAug(method='minmax')
augmented_data = aug.augment(data)

librosa_display.waveplot(data, sr=sr, alpha=0.5)
librosa_display.waveplot(augmented_data, sr=sr, color='r', alpha=0.25)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Polarity Inversion Augmenter

# %%
aug = naa.PolarityInverseAug()
augmented_data = aug.augment(data)

librosa_display.waveplot(data, sr=sr, alpha=0.5)
librosa_display.waveplot(augmented_data, sr=sr, color='r', alpha=0.25)

plt.tight_layout()
plt.show()
